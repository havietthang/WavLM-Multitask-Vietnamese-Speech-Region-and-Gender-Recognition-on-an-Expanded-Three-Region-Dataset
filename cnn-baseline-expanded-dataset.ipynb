# %% [markdown]
# # Extract features

# %%
import os
import glob
import librosa
import librosa.display
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
import pandas as pd

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

csv_path = "/kaggle/input/datasets/lnt0821/srr-sgr-dataset-2-0/SRR_SGR_Dataset_train.csv"

df = pd.read_csv(csv_path)

# Clean column names
df.columns = df.columns.str.strip()

# Clean region values
df['region'] = df['region'].astype(str).str.strip()

print("Unique region labels:", df['region'].unique())

# Nếu dataset dùng số
region_map = {
    '1': 'North',
    '2': 'Central',
    '3': 'South'
}

df['region'] = df['region'].replace(region_map)

# Đếm
region_counts = df['region'].value_counts()

print("\nRegion Counts:")
print(region_counts)

# Plot
region_order = ['North','Central','South']
counts = [region_counts.get(r,0) for r in region_order]

plt.figure(figsize=(10,6))
sns.barplot(x=region_order, y=counts, palette="colorblind")

plt.xlabel("Region")
plt.ylabel("Count")
plt.title("Region Distribution on Train")
plt.tight_layout()
plt.show()
# Out:
# Unique region labels: ['1' '2' '3']
#
# Region Counts:
# region
# Central    3632
# North      3395
# South      3113
# Name: count, dtype: int64
# /tmp/ipykernel_26/1693510288.py:37: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=region_order, y=counts, palette="colorblind")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

csv_path = "/kaggle/input/datasets/lnt0821/srr-sgr-dataset-2-0/SRR_SGR_Dataset_train.csv"

df = pd.read_csv(csv_path)

# Clean column names
df.columns = df.columns.str.strip()

# Clean gender values
df['gender'] = df['gender'].astype(str).str.strip()

print("Unique gender labels:", df['gender'].unique())

# Nếu dataset dùng số
gender_map = {
    '0': 'Male',
    '1': 'Female'
}
df['gender'] = df['gender'].replace(gender_map)

# Đếm
gender_counts = df['gender'].value_counts()

print("\ngender Counts:")
print(gender_counts)

# Plot
gender_order = ['Male', 'Female']
counts = [gender_counts.get(r,0) for r in gender_order]

plt.figure(figsize=(10,6))
sns.barplot(x=gender_order, y=counts, palette="colorblind")

plt.xlabel("gender")
plt.ylabel("Count")
plt.title("gender Distribution on Train")
plt.tight_layout()
plt.show()
# Out:
# Unique gender labels: ['1' '0']
#
# gender Counts:
# gender
# Male      6696
# Female    3444
# Name: count, dtype: int64
# /tmp/ipykernel_26/2407739859.py:35: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=gender_order, y=counts, palette="colorblind")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

csv_path = "/kaggle/input/datasets/lnt0821/srr-sgr-dataset-2-0/SRR_SGR_Dataset_val.csv"

df = pd.read_csv(csv_path)

# Clean column names
df.columns = df.columns.str.strip()

# Clean region values
df['region'] = df['region'].astype(str).str.strip()

print("Unique region labels:", df['region'].unique())

# Nếu dataset dùng số
region_map = {
    '1': 'North',
    '2': 'Central',
    '3': 'South'
}

df['region'] = df['region'].replace(region_map)

# Đếm
region_counts = df['region'].value_counts()

print("\nRegion Counts:")
print(region_counts)

# Plot
region_order = ['North','Central','South']
counts = [region_counts.get(r,0) for r in region_order]

plt.figure(figsize=(10,6))
sns.barplot(x=region_order, y=counts, palette="colorblind")

plt.xlabel("Region")
plt.ylabel("Count")
plt.title("Region Distribution on Val")
plt.tight_layout()
plt.show()
# Out:
# Unique region labels: ['1' '2' '3']
#
# Region Counts:
# region
# Central    1074
# North      1067
# South       923
# Name: count, dtype: int64
# /tmp/ipykernel_26/2735906924.py:37: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=region_order, y=counts, palette="colorblind")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

csv_path = "/kaggle/input/datasets/lnt0821/srr-sgr-dataset-2-0/SRR_SGR_Dataset_val.csv"

df = pd.read_csv(csv_path)

# Clean column names
df.columns = df.columns.str.strip()

# Clean gender values
df['gender'] = df['gender'].astype(str).str.strip()

print("Unique gender labels:", df['gender'].unique())

# Nếu dataset dùng số
gender_map = {
    '0': 'Male',
    '1': 'Female'
}
df['gender'] = df['gender'].replace(gender_map)

# Đếm
gender_counts = df['gender'].value_counts()

print("\ngender Counts:")
print(gender_counts)

# Plot
gender_order = ['Male', 'Female']
counts = [gender_counts.get(r,0) for r in gender_order]

plt.figure(figsize=(10,6))
sns.barplot(x=gender_order, y=counts, palette="colorblind")

plt.xlabel("gender")
plt.ylabel("Count")
plt.title("gender Distribution on Val")
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_26/3580906126.py:35: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=gender_order, y=counts, palette="colorblind")
# Unique gender labels: ['1' '0']
#
# gender Counts:
# gender
# Male      2059
# Female    1005
# Name: count, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

csv_path = "/kaggle/input/datasets/lnt0821/srr-sgr-dataset-2-0/SRR_SGR_Dataset_test.csv"

df = pd.read_csv(csv_path)

# Clean column names
df.columns = df.columns.str.strip()

# Clean region values
df['region'] = df['region'].astype(str).str.strip()

print("Unique region labels:", df['region'].unique())

# Nếu dataset dùng số
region_map = {
    '1': 'North',
    '2': 'Central',
    '3': 'South'
}

df['region'] = df['region'].replace(region_map)

# Đếm
region_counts = df['region'].value_counts()

print("\nRegion Counts:")
print(region_counts)

# Plot
region_order = ['North','Central','South']
counts = [region_counts.get(r,0) for r in region_order]

plt.figure(figsize=(10,6))
sns.barplot(x=region_order, y=counts, palette="colorblind")

plt.xlabel("Region")
plt.ylabel("Count")
plt.title("Region Distribution on Test")
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_26/3217624975.py:37: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=region_order, y=counts, palette="colorblind")
# Unique region labels: ['1' '2' '3']
#
# Region Counts:
# region
# North      1252
# South       852
# Central     848
# Name: count, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

csv_path = "/kaggle/input/datasets/lnt0821/srr-sgr-dataset-2-0/SRR_SGR_Dataset_test.csv"

df = pd.read_csv(csv_path)

# Clean column names
df.columns = df.columns.str.strip()

# Clean gender values
df['gender'] = df['gender'].astype(str).str.strip()

print("Unique gender labels:", df['gender'].unique())

# Nếu dataset dùng số
gender_map = {
    '0': 'Male',
    '1': 'Female'
}
df['gender'] = df['gender'].replace(gender_map)

# Đếm
gender_counts = df['gender'].value_counts()

print("\ngender Counts:")
print(gender_counts)

# Plot
gender_order = ['Male', 'Female']
counts = [gender_counts.get(r,0) for r in gender_order]

plt.figure(figsize=(10,6))
sns.barplot(x=gender_order, y=counts, palette="colorblind")

plt.xlabel("gender")
plt.ylabel("Count")
plt.title("gender Distribution on Test")
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_26/104121946.py:35: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=gender_order, y=counts, palette="colorblind")
# Unique gender labels: ['0' '1']
#
# gender Counts:
# gender
# Male      1967
# Female     985
# Name: count, dtype: int64

# %% [markdown]
# # Split Dataset

# %%
train_df_U = pd.read_csv('/kaggle/input/datasets/lnt0821/srr-sgr-dataset-2-0/SRR_SGR_Dataset_train.csv')
val_df_U = pd.read_csv('/kaggle/input/datasets/lnt0821/srr-sgr-dataset-2-0/SRR_SGR_Dataset_val.csv')
test_df_U = pd.read_csv('/kaggle/input/datasets/lnt0821/srr-sgr-dataset-2-0/SRR_SGR_Dataset_test.csv')

# %%
test_df_U
# Out:
#           mfcc_0      mfcc_1     mfcc_2     mfcc_3     mfcc_4     mfcc_5  \
# 0    -169.770279  185.407639  -1.908256  49.999596  -1.000336  25.627916
# 1    -192.485626  183.057785 -11.936643  55.986431   2.237294  11.027076
# 2    -157.306061  172.629486 -37.396805  62.904053  -3.629430  20.848248
# 3    -108.462059  181.001083 -44.093689  41.227375 -29.388460  -1.117248
# 4    -163.403290  189.286331 -14.376945  58.952072  -2.315500  21.545864
# ...          ...         ...        ...        ...        ...        ...
# 2947 -267.846344  162.278122  -2.814818  36.344280  -0.258409  -1.089527
# 2948 -364.761414  171.939133  20.913527  31.690578   9.640165   1.171666
# 2949 -295.610596  169.324829 -33.561687  -4.870221 -34.315937  -6.203812
# 2950 -252.911896  167.796692 -28.848749  42.332863   1.460708   1.015688
# 2951 -304.049103  180.740829   8.784263   1.945593   4.373306   1.393662
#
#          mfcc_6     mfcc_7     mfcc_8     mfcc_9  ...  chroma_6  chroma_7  \
# 0    -22.239567  -2.943290   2.142119  -3.458215  ...  0.262769  0.232778
# 1    -23.083389  -0.012919  11.852790  -4.670839  ...  0.147247  0.218813
# 2    -17.059227   3.055895   0.312338  -6.475612  ...  0.521064  0.470801
# 3    -28.015003  -4.819160  -8.950972 -21.394945  ...  0.650478  0.275648
# 4    -13.594834  -1.908999   5.495642  -4.962269  ...  0.450488  0.385731
# ...         ...        ...        ...        ...  ...       ...       ...
# 2947  -0.705158 -10.431991  -6.613412 -12.167678  ...  0.573289  0.446625
# 2948   7.861950  -8.282817  -8.558780   3.551114  ...  0.600940  0.566568
# 2949 -12.227361 -17.265472 -15.534044  -5.402484  ...  0.457682  0.391816
# 2950  -5.859215 -13.848275  -5.513379  -3.925116  ...  0.403031  0.351517
# 2951  -4.881502 -16.947271  -9.797057  -4.360611  ...  0.359654  0.366912
#
#       chroma_8  chroma_9  chroma_10  chroma_11  spectral_centroid  \
# 0     0.306502  0.371416   0.494087   0.280911        1431.711464
# 1     0.349929  0.385024   0.553170   0.408977        1451.575285
# 2     0.464265  0.477953   0.571811   0.481537        2218.735371
# 3     0.279367  0.359898   0.571695   0.297473        1877.773878
# 4     0.476272  0.499742   0.625194   0.343956        1494.212894
# ...        ...       ...        ...        ...                ...
# 2947  0.292651  0.234423   0.237413   0.228028        1723.144865
# 2948  0.490930  0.421617   0.421151   0.428533        1345.446967
# 2949  0.404188  0.459272   0.491969   0.474199        2110.442762
# 2950  0.384598  0.461104   0.550148   0.565343        2106.953139
# 2951  0.305810  0.223973   0.217558   0.209913        1129.431729
#
#       spectral_bandwidth  region  gender
# 0            2453.514220       1       0
# 1            2340.499417       1       0
# 2            2571.655423       1       0
# 3            2479.307096       1       0
# 4            2368.475028       1       0
# ...                  ...     ...     ...
# 2947         2254.247818       1       1
# 2948         2144.447799       1       0
# 2949         2531.320515       3       0
# 2950         2557.054844       3       0
# 2951         1927.704813       2       0
#
# [2952 rows x 56 columns]

# %%
Xr_train = train_df_U.copy().iloc[:,0:-2].values
Xr_dev = val_df_U.copy().iloc[:,0:-2].values
Xr_test = test_df_U.copy().iloc[:,0:-2].values

yr_train = train_df_U.copy()['region'].values
yr_dev = val_df_U.copy()['region'].values
yr_test = test_df_U.copy()['region'].values

Xg_train = train_df_U.copy().iloc[:,0:-2].values
Xg_dev = val_df_U.copy().iloc[:,0:-2].values
Xg_test = test_df_U.copy().iloc[:,0:-2].values

yg_train = train_df_U.copy()['gender'].values
yg_dev = val_df_U.copy()['gender'].values
yg_test = test_df_U.copy()['gender'].values

# %%
len(Xr_train[1])
# Out:
# 54

# %% [markdown]
# # Prepare 2D data for CNN Model

# %%
# !pip uninstall -y numpy scikit-learn
# !pip install numpy==1.26.4
# !pip install scikit-learn==1.2.2 keras-tuner

# %%
# import os
# os._exit(0)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization, LeakyReLU, Dropout, Input, Activation, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
import keras_tuner as kt
from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import sklearn
print("Phiên bản scikit-learn:", sklearn.__version__)
# Out:
# 2026-03-05 10:33:47.454587: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1772706827.650969      26 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1772706827.712197      26 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1772706828.180011      26 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772706828.180076      26 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772706828.180079      26 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772706828.180082      26 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Phiên bản scikit-learn: 1.6.1

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import pandas as pd
from sklearn.model_selection import train_test_split
import joblib
import sklearn
print("Phiên bản scikit-learn:", sklearn.__version__)

# Hàm chuyển sang 2D
def convert_1dto2d(input_1d):
    num_samples = input_1d.shape[0]
    output_2d = np.zeros((num_samples, 7, 10, 1))
    for i in range(num_samples):
        mfcc = input_1d[i, :40].reshape(4, 10)
        chroma = input_1d[i, 40:52].reshape(2, 6)
        spectral = input_1d[i, 52:54].reshape(1, 2)
        chroma_padded = np.pad(chroma, ((0, 0), (0, 4)), mode='constant')
        spectral_padded = np.pad(spectral, ((0, 0), (0, 8)), mode='constant')
        matrix_2d = np.vstack((mfcc, chroma_padded, spectral_padded))
        output_2d[i] = matrix_2d[..., np.newaxis]
    return output_2d


def make2dData( X_train, X_dev, X_test, name):
    
    scaler_mfcc = StandardScaler()
    scaler_chroma = MinMaxScaler()
    scaler_spectral = StandardScaler()
    
    # Chỉ fit trên tập train
    X_train_mfcc = scaler_mfcc.fit_transform(X_train[:, :40])
    X_train_chroma = scaler_chroma.fit_transform(X_train[:, 40:52])
    X_train_spectral = scaler_spectral.fit_transform(X_train[:, 52:54])
    
    X_dev_mfcc = scaler_mfcc.transform(X_dev[:, :40])
    X_dev_chroma = scaler_chroma.transform(X_dev[:, 40:52])
    X_dev_spectral = scaler_spectral.transform(X_dev[:, 52:54])
    
    X_test_mfcc = scaler_mfcc.transform(X_test[:, :40])
    X_test_chroma = scaler_chroma.transform(X_test[:, 40:52])
    X_test_spectral = scaler_spectral.transform(X_test[:, 52:54])

    # Lưu lại scaler để dùng cho dữ liệu thực tế sau này
    joblib.dump(scaler_mfcc, f"scaler_mfcc_{name}.pkl")
    joblib.dump(scaler_chroma, f"scaler_chroma_{name}.pkl")
    joblib.dump(scaler_spectral, f"scaler_spectral_{name}.pkl")
    
    # Gộp lại sau khi scale
    X_train_scaled = np.hstack((X_train_mfcc, X_train_chroma, X_train_spectral))
    X_dev_scaled = np.hstack((X_dev_mfcc, X_dev_chroma, X_dev_spectral))
    X_test_scaled = np.hstack((X_test_mfcc, X_test_chroma, X_test_spectral))
    
    X_train_2D = convert_1dto2d(X_train_scaled)
    X_dev_2D = convert_1dto2d(X_dev_scaled)
    X_test_2D = convert_1dto2d(X_test_scaled)
    
    
    return X_train_2D, X_dev_2D, X_test_2D


Xr_train_2D, Xr_dev_2D, Xr_test_2D = make2dData(Xr_train, Xr_dev, Xr_test, 'reg-update')
Xg_train_2D, Xg_dev_2D, Xg_test_2D = make2dData(Xg_train, Xg_dev, Xg_test, 'gen-update')

# Trực quan hóa một mẫu
sample_index = 0  # Chọn mẫu đầu tiên
sample = Xr_train_2D[sample_index, :, :, 0]  # Lấy dữ liệu 2D (7x10)

plt.figure(figsize=(8, 6))
plt.imshow(sample, cmap='viridis', aspect='auto')
plt.colorbar(label='Value')
plt.title(f'Sample {sample_index} - 2D Representation (7x10)')
plt.xlabel('Feature Index')
plt.ylabel('Row Index')
plt.show()

print("Sample values:\n", sample)
# Out:
# Phiên bản scikit-learn: 1.6.1
# Sample values:
#  [[ 1.1074523  -0.99568625 -0.67922823  0.56090124 -3.03398816  0.04143721
#   -1.14350048  0.8879252  -0.57665303 -1.01425441]
#  [ 1.1834274  -0.40721762 -1.3008136  -2.0965336  -0.60681344 -2.34439163
#   -2.14794005 -0.90554038  0.25471506 -2.59794333]
#  [-0.83624925  1.8841313   0.63737243  2.04066917  3.0345091   1.96256132
#    0.62216337  1.5050685   0.23880583  1.32051362]
#  [ 0.65015834  0.07465217  1.10706229 -1.01569759 -0.20817682 -1.54422522
#   -1.75112689 -0.16670608  0.21335763  0.53061155]
#  [ 0.24645514  0.42337558  0.26137917  0.24323582  0.36522061  0.38262485
#    0.          0.          0.          0.        ]
#  [ 0.38218846  0.26590674  0.43543051  0.19768574  0.15405354  0.32643339
#    0.          0.          0.          0.        ]
#  [ 1.28427183  1.32740996  0.          0.          0.          0.
#    0.          0.          0.          0.        ]]

# %%
yr_train_cat = tf.keras.utils.to_categorical(yr_train -1, 3)  
yr_dev_cat = tf.keras.utils.to_categorical(yr_dev -1, 3)
yr_test_cat = tf.keras.utils.to_categorical(yr_test -1, 3)

yg_train_cat = tf.keras.utils.to_categorical(yg_train, 2) 
yg_dev_cat = tf.keras.utils.to_categorical(yg_dev, 2)
yg_test_cat = tf.keras.utils.to_categorical(yg_test, 2)

# %% [markdown]
# # Initialize Callbacks and Evaluate function

# %%
# Callbacks
def Callbacks(model):
    early_stopping = EarlyStopping(
        monitor='val_accuracy',  # Theo dõi độ chính xác trên tập validation
        patience=20,  # Chờ 20 epoch trước khi dừng
        restore_best_weights=True,  # Khôi phục trọng số tốt nhất
        mode='max',  # Tối đa hóa độ chính xác
        verbose=1  # Hiển thị thông báo
    )
    
    lr_reducer = ReduceLROnPlateau(
        monitor='val_loss',  # Theo dõi mất mát trên tập validation
        factor=0.3,  # Giảm learning rate xuống 30% khi không cải thiện
        patience=8,  # Chờ 8 epoch trước khi giảm
        min_lr=1e-6,  # Learning rate tối thiểu
        verbose=1  
    )
    
    checkpoint = tf.keras.callbacks.ModelCheckpoint(
        f'best_{model}.keras',  # Lưu mô hình tốt nhất dưới dạng 'best_model.keras'
        monitor='val_accuracy',  # Theo dõi độ chính xác trên tập validation
        save_best_only=True,  # Chỉ lưu khi có cải thiện
        mode='max',  # Tối đa hóa độ chính xác
        verbose=1 
    )
    return lr_reducer, checkpoint, early_stopping

# %%
def Evaluateandlogperformance(model, history, X_test, y_test_cat,name ,detail=False):
    if detail:
        # Tải mô hình tốt nhất và đánh giá
        best_model = tf.keras.models.load_model(f'/kaggle/working/best_{name}.keras')
        # test_loss, test_accuracy = best_model.evaluate(X_test_scaled, y_test_cat)
        test_loss, test_accuracy = best_model.evaluate(X_test, y_test_cat)
        print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}")
        dev_loss, dev_accuracy = best_model.evaluate(X_dev, y_dev_cat)
        print(f"Dev Loss: {dev_loss:.4f}, Dev Accuracy: {dev_accuracy:.4f}")
    
        # Ghi lại chi tiết hiệu suất
        print("\nDetailed Performance Summary:") 
        print(f"Training final accuracy: {history.history['accuracy'][-1]:.4f}")  
        print(f"Validation final accuracy: {history.history['val_accuracy'][-1]:.4f}")  
        print(f"Test final accuracy: {test_accuracy:.4f}")  
        print(f"Training final loss: {history.history['loss'][-1]:.4f}")  
        print(f"Validation final loss: {history.history['val_loss'][-1]:.4f}") 
        print(f"Test final loss: {test_loss:.4f}")  
        # Kiểm tra xem mục tiêu hiệu suất có đạt được không
        if dev_accuracy >= 0.8: 
            print("\n🎉 Target accuracy of 0.8 achieved on validation set!")  
        else:
            print("\n⚠️ Accuracy target of 0.8 not reached. Consider further improvements.") 


        
    # Sau khi huấn luyện xong, tính test accuracy và test loss
    test_loss, test_accuracy = model.evaluate(X_test, y_test_cat)  # Đánh giá mô hình trên tập kiểm tra

    
    # Vẽ biểu đồ lịch sử huấn luyện
    plt.figure(figsize=(12, 4))  # Tạo khung biểu đồ với kích thước 12x4
    
    plt.subplot(1, 2, 1)  # Biểu đồ con đầu tiên (bên trái)
    
    plt.plot(history.history['accuracy'], label='Training Accuracy')  # Vẽ đường độ chính xác huấn luyện
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')  # Vẽ đường độ chính xác validation
    plt.axhline(y=test_accuracy, color='r', linestyle='--', label='Test Accuracy')  # Vẽ đường ngang độ chính xác kiểm tra
    # Thêm văn bản để hiển thị giá trị test accuracy
    # Tự điều chỉnh vị trí chữ để không bị che
    acc_text_y = test_accuracy + 0.02 if test_accuracy < 0.97 else test_accuracy - 0.05
    
    plt.text(
        len(history.history['accuracy']) * 0.5,
        acc_text_y,
        f'{test_accuracy:.2f}',
        color='g', ha='center', va='bottom'
    )

    plt.title(f'Model Accuracy {name}')  
    plt.xlabel('Epoch')  # Nhãn trục x là Epoch
    plt.ylabel('Accuracy')  # Nhãn trục y là Độ chính xác
    plt.legend()  # Hiển thị chú thích
    
    plt.subplot(1, 2, 2)  
    
    plt.plot(history.history['loss'], label='Training Loss')  # Vẽ đường mất mát huấn luyện
    plt.plot(history.history['val_loss'], label='Validation Loss')  # Vẽ đường mất mát validation
    plt.axhline(y=test_loss, color='r', linestyle='--', label='Test Loss')  # Vẽ đường ngang mất mát kiểm tra
    # Thêm văn bản để hiển thị giá trị test loss
    plt.text(len(history.history['loss']) * 0.5, test_loss + 0.02,  # Vị trí giữa trục x, trên đường kiểm tra
             f'{test_loss:.2f}',  # Giá trị mất mát với 2 chữ số thập phân
             color='g', ha='center', va='bottom') 
    plt.title(f'Model Loss {name}')  
    plt.xlabel('Epoch')  
    plt.ylabel('Loss') 
    plt.legend() 
    
    plt.figure(constrained_layout=True)   # Điều chỉnh lề để tránh lỗi
    plt.show()

# %%
def compute_confusion_matrix(model, X_test, y_test, name, num_classes):
    # Dự đoán trên tập kiểm tra
    y_pred = model.predict(X_test)
    y_pred_classes = np.argmax(y_pred, axis=1)  # Chuyển dự đoán từ xác suất sang lớp (class) bằng cách lấy giá trị lớn nhất
    y_test_classes = np.argmax(y_test, axis=1) # Chuyển nhãn thực tế từ dạng one-hot encoding sang lớp (class)
    
    # Tính ma trận nhầm lẫn
    cm = confusion_matrix(y_test_classes, y_pred_classes)
    
    # Vẽ ma trận nhầm lẫn
    plt.figure(figsize=(10, 8))  # Đặt kích thước biểu đồ
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')  # Vẽ heatmap với số liệu chú thích
    plt.title(f'Confusion Matrix {name}')  
    plt.ylabel('True Label')  # Nhãn trục y: Nhãn thực tế
    plt.xlabel('Predicted Label')  # Nhãn trục x: Nhãn dự đoán
    plt.show()  
    
    # In báo cáo phân loại chi tiết (Precision, Recall, F1-score)
    print("\nClassification Report:")
    print(classification_report(y_test_classes, y_pred_classes))
    
    # Tính và in Precision, Recall trung bình theo từng lớp
    report = classification_report(y_test_classes, y_pred_classes, output_dict=True)
    print("\nDetailed Metrics by Class:")  # Chỉ số chi tiết theo lớp
    for i in range(num_classes):  # Lặp qua từng lớp
        print(f"\nClass {i}:")  # Lớp {i}
        print(f"Precision: {report[str(i)]['precision']:.4f}")  # Độ chính xác: tỷ lệ dự đoán đúng trong số dự đoán
        print(f"Recall: {report[str(i)]['recall']:.4f}")  # Độ nhạy: tỷ lệ phát hiện đúng các mẫu thực tế
        print(f"F1-score: {report[str(i)]['f1-score']:.4f}")  # F1-score: trung bình điều hòa của Precision và Recall
    
    # Tính và in các chỉ số trung bình (Hiển thị các chỉ số trung bình gia quyền của toàn bộ mô hình)
    print("\nOverall Metrics:")  # Chỉ số tổng thể
    print(f"Average Precision: {report['weighted avg']['precision']:.4f}")  # Độ chính xác trung bình
    print(f"Average Recall: {report['weighted avg']['recall']:.4f}")  # Độ nhạy trung bình
    print(f"Average F1-score: {report['weighted avg']['f1-score']:.4f}")  # F1-score trung bình

# %% [markdown]
# # Model

# %%
# U, its mean Update.

CNN2DRegionU = Sequential()

# First Conv2D layer
CNN2DRegionU.add(Conv2D(
    filters=96,  # filters_0
    kernel_size=5,  # kernel_size_0
    strides=1,
    padding='same',
    activation='relu',
    input_shape=(7, 10, 1),
    kernel_regularizer=l2(0.008732453502912857)  # l2_conv_0
))
CNN2DRegionU.add(BatchNormalization())
CNN2DRegionU.add(MaxPooling2D(
    pool_size=2,  # pool_size_0
    strides=1,  # pool_strides_0
    padding='same'
))

# Second Conv2D layer
CNN2DRegionU.add(Conv2D(
    filters=64,  # filters_1
    kernel_size=5,  # kernel_size_1
    strides=1,
    padding='same',
    activation='relu',
    kernel_regularizer=l2(0.0008307655913624025)  # l2_conv_1
))
CNN2DRegionU.add(BatchNormalization())

# Dropout after Conv2D layers
CNN2DRegionU.add(Dropout(rate=0.2))  # dropout_conv

# Flatten layer
CNN2DRegionU.add(Flatten())

# First Dense layer
CNN2DRegionU.add(Dense(
    units=96,  # units_0
    activation='relu',
    kernel_regularizer=l2(0.00036558483095598383)  # l2_dense_0
))
CNN2DRegionU.add(BatchNormalization())
CNN2DRegionU.add(Dropout(rate=0.3))  # dropout_dense_0

# Second Dense layer
CNN2DRegionU.add(Dense(
    units=16,  # units_1
    activation='relu',
    kernel_regularizer=l2(0.0001129701550594694)  # l2_dense_1
))
CNN2DRegionU.add(BatchNormalization())
CNN2DRegionU.add(Dropout(rate=0.2))  # dropout_dense_1

# Output layer
CNN2DRegionU.add(Dense(3, activation='softmax'))

# Compile the model
CNN2DRegionU.compile(
    optimizer=Adam(learning_rate=0.00021682255492865924),  # learning_rate 
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Display model summary
CNN2DRegionU.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# I0000 00:00:1772706853.678305      26 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15511 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 7, 10, 96)      │         2,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 7, 10, 96)      │           384 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 7, 10, 96)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 7, 10, 64)      │       153,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 7, 10, 64)      │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 7, 10, 64)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 4480)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 96)             │       430,176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 96)             │           384 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 96)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 16)             │         1,552 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 16)             │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 3)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 589,027 (2.25 MB)
#  Trainable params: 588,483 (2.24 MB)
#  Non-trainable params: 544 (2.12 KB)

# %%
CNN2DGenderU = Sequential()

# First Conv2D layer
CNN2DGenderU.add(Conv2D(
    filters=96,  # filters_0
    kernel_size=5,  # kernel_size_0
    strides=1,
    padding='same',
    activation='relu',
    input_shape=(7, 10, 1),
    kernel_regularizer=l2(0.008732453502912857)  # l2_conv_0
))
CNN2DGenderU.add(BatchNormalization())
CNN2DGenderU.add(MaxPooling2D(
    pool_size=2,  # pool_size_0
    strides=1,  # pool_strides_0
    padding='same'
))

# Second Conv2D layer
CNN2DGenderU.add(Conv2D(
    filters=64,  # filters_1
    kernel_size=5,  # kernel_size_1
    strides=1,
    padding='same',
    activation='relu',
    kernel_regularizer=l2(0.0008307655913624025)  # l2_conv_1
))
CNN2DGenderU.add(BatchNormalization())

# Dropout after Conv2D layers
CNN2DGenderU.add(Dropout(rate=0.2))  # dropout_conv

# Flatten layer
CNN2DGenderU.add(Flatten())

# First Dense layer
CNN2DGenderU.add(Dense(
    units=96,  # units_0
    activation='relu',
    kernel_regularizer=l2(0.00036558483095598383)  # l2_dense_0
))
CNN2DGenderU.add(BatchNormalization())
CNN2DGenderU.add(Dropout(rate=0.3))  # dropout_dense_0

# Second Dense layer
CNN2DGenderU.add(Dense(
    units=16,  # units_1
    activation='relu',
    kernel_regularizer=l2(0.0001129701550594694)  # l2_dense_1
))
CNN2DGenderU.add(BatchNormalization())
CNN2DGenderU.add(Dropout(rate=0.2))  # dropout_dense_1

# Output layer
CNN2DGenderU.add(Dense(2, activation='softmax'))

# Compile the model
CNN2DGenderU.compile(
    optimizer=Adam(learning_rate=0.00021682255492865924),  # learning_rate 
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Display model summary
CNN2DGenderU.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_2 (Conv2D)               │ (None, 7, 10, 96)      │         2,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 7, 10, 96)      │           384 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 7, 10, 96)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 7, 10, 64)      │       153,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 7, 10, 64)      │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 7, 10, 64)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 4480)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 96)             │       430,176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 96)             │           384 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 96)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 16)             │         1,552 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 16)             │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 2)              │            34 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 589,010 (2.25 MB)
#  Trainable params: 588,466 (2.24 MB)
#  Non-trainable params: 544 (2.12 KB)

# %%
lr_reducer, checkpoint, early_stopping = Callbacks('CNN2DRegionU')
# Huấn luyện
historyCNN2DRegionU = CNN2DRegionU.fit(
    Xr_train_2D,  # Dữ liệu huấn luyện tăng cường
    yr_train_cat,  # Nhãn huấn luyện dạng one-hot
    epochs=200, 
    batch_size=64,  
    validation_data=(Xr_dev_2D, yr_dev_cat),  # Dữ liệu validation
    callbacks=[lr_reducer, checkpoint, early_stopping],  # Sử dụng các callback
    verbose=1  # Hiển thị tiến trình huấn luyện
)
# Out:
# Epoch 1/200
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1772706858.213137      69 service.cc:152] XLA service 0x78fa0c008880 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1772706858.213171      69 service.cc:160]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1772706858.807942      69 cuda_dnn.cc:529] Loaded cuDNN version 91002
#  43/159 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3854 - loss: 1.5278
# I0000 00:00:1772706863.152342      69 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.4663 - loss: 1.3205
# Epoch 1: val_accuracy improved from -inf to 0.30385, saving model to best_CNN2DRegionU.keras
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 14s 38ms/step - accuracy: 0.4667 - loss: 1.3196 - val_accuracy: 0.3039 - val_loss: 1.3391 - learning_rate: 2.1682e-04
# Epoch 2/200
# 145/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6579 - loss: 0.9317
# Epoch 2: val_accuracy improved from 0.30385 to 0.41123, saving model to best_CNN2DRegionU.keras
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6588 - loss: 0.9302 - val_accuracy: 0.4112 - val_loss: 1.2697 - learning_rate: 2.1682e-04
# Epoch 3/200
# 145/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7126 - loss: 0.8393
# Epoch 3: val_accuracy improved from 0.41123 to 0.53003, saving model to best_CNN2DRegionU.keras
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7133 - loss: 0.8380 - val_accuracy: 0.5300 - val_loss: 1.1764 - learning_rate: 2.1682e-04
# Epoch 4/200
# 144/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7516 - loss: 0.7531
# Epoch 4: val_accuracy improved from 0.53003 to 0.53133, saving model to best_CNN2DRegionU.keras
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7515 - loss: 0.7529 - val_accuracy: 0.5313 - val_loss: 1.1853 - learning_rate: 2.1682e-04
# Epoch 5/200
# 145/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7833 - loss: 0.6892
# Epoch 5: val_accuracy improved from 0.53133 to 0.56495, saving model to best_CNN2DRegionU.keras
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7831 - loss: 0.6893 - val_accuracy: 0.5649 - val_loss: 1.1783 - learning_rate: 2.1682e-04
# Epoch 6/200
# 145/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8071 - loss: 0.6411
# Epoch 6: val_accuracy did not improve from 0.56495
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8066 - loss: 0.6419 - val_accuracy: 0.5434 - val_loss: 1.2539 - learning_rate: 2.1682e-04
# Epoch 7/200
# 145/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8178 - loss: 0.6158
# Epoch 7: val_accuracy did not improve from 0.56495
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8179 - loss: 0.6152 - val_accuracy: 0.5610 - val_loss: 1.2168 - learning_rate: 2.1682e-04
# Epoch 8/200
# 145/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8400 - loss: 0.5583
# Epoch 8: val_accuracy did not improve from 0.56495
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8397 - loss: 0.5592 - val_accuracy: 0.5395 - val_loss: 1.3051 - learning_rate: 2.1682e-04
# Epoch 9/200
# 145/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8499 - loss: 0.5390
# Epoch 9: val_accuracy did not improve from 0.56495
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8499 - loss: 0.5389 - val_accuracy: 0.5271 - val_loss: 1.3775 - learning_rate: 2.1682e-04
# Epoch 10/200
# 150/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8712 - loss: 0.5003
# Epoch 10: val_accuracy did not improve from 0.56495
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8708 - loss: 0.5008 - val_accuracy: 0.5183 - val_loss: 1.3810 - learning_rate: 2.1682e-04
# Epoch 11/200
# 144/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8764 - loss: 0.4834
# Epoch 11: ReduceLROnPlateau reducing learning rate to 6.504676857730373e-05.
#
# Epoch 11: val_accuracy did not improve from 0.56495
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8763 - loss: 0.4834 - val_accuracy: 0.5049 - val_loss: 1.4739 - learning_rate: 2.1682e-04
# Epoch 12/200
# 145/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9064 - loss: 0.4293
# Epoch 12: val_accuracy did not improve from 0.56495
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9064 - loss: 0.4286 - val_accuracy: 0.5555 - val_loss: 1.3379 - learning_rate: 6.5047e-05
# Epoch 13/200
# 145/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9222 - loss: 0.3831
# Epoch 13: val_accuracy did not improve from 0.56495
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9219 - loss: 0.3837 - val_accuracy: 0.5444 - val_loss: 1.4020 - learning_rate: 6.5047e-05
# Epoch 14/200
# 145/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9287 - loss: 0.3703
# Epoch 14: val_accuracy did not improve from 0.56495
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9285 - loss: 0.3702 - val_accuracy: 0.5568 - val_loss: 1.3875 - learning_rate: 6.5047e-05
# Epoch 15/200
# 145/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9310 - loss: 0.3563
# Epoch 15: val_accuracy did not improve from 0.56495
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9308 - loss: 0.3566 - val_accuracy: 0.5317 - val_loss: 1.4323 - learning_rate: 6.5047e-05
# Epoch 16/200
# 145/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9388 - loss: 0.3383
# Epoch 16: val_accuracy did not improve from 0.56495
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9388 - loss: 0.3383 - val_accuracy: 0.5597 - val_loss: 1.3736 - learning_rate: 6.5047e-05
# Epoch 17/200
# 145/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9401 - loss: 0.3282
# Epoch 17: val_accuracy did not improve from 0.56495
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9401 - loss: 0.3285 - val_accuracy: 0.5457 - val_loss: 1.4646 - learning_rate: 6.5047e-05
# Epoch 18/200
# 145/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9473 - loss: 0.3140
# Epoch 18: val_accuracy did not improve from 0.56495
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9472 - loss: 0.3144 - val_accuracy: 0.5411 - val_loss: 1.4705 - learning_rate: 6.5047e-05
# Epoch 19/200
# 145/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9513 - loss: 0.3040
# Epoch 19: ReduceLROnPlateau reducing learning rate to 1.9514031009748578e-05.
#
# Epoch 19: val_accuracy did not improve from 0.56495
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9510 - loss: 0.3045 - val_accuracy: 0.5473 - val_loss: 1.4480 - learning_rate: 6.5047e-05
# Epoch 20/200
# 144/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9519 - loss: 0.2956
# Epoch 20: val_accuracy did not improve from 0.56495
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9524 - loss: 0.2950 - val_accuracy: 0.5542 - val_loss: 1.4755 - learning_rate: 1.9514e-05
# Epoch 21/200
# 145/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9635 - loss: 0.2796
# Epoch 21: val_accuracy did not improve from 0.56495
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9634 - loss: 0.2795 - val_accuracy: 0.5584 - val_loss: 1.4621 - learning_rate: 1.9514e-05
# Epoch 22/200
# 157/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9622 - loss: 0.2753
# Epoch 22: val_accuracy did not improve from 0.56495
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9622 - loss: 0.2754 - val_accuracy: 0.5539 - val_loss: 1.4822 - learning_rate: 1.9514e-05
# Epoch 23/200
# 144/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9625 - loss: 0.2782
# Epoch 23: val_accuracy did not improve from 0.56495
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9627 - loss: 0.2778 - val_accuracy: 0.5578 - val_loss: 1.4770 - learning_rate: 1.9514e-05
# Epoch 24/200
# 145/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9645 - loss: 0.2721
# Epoch 24: val_accuracy did not improve from 0.56495
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9648 - loss: 0.2716 - val_accuracy: 0.5532 - val_loss: 1.5050 - learning_rate: 1.9514e-05
# Epoch 25/200
# 153/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9649 - loss: 0.2663
# Epoch 25: val_accuracy did not improve from 0.56495
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9649 - loss: 0.2661 - val_accuracy: 0.5578 - val_loss: 1.4985 - learning_rate: 1.9514e-05
# Epoch 25: early stopping
# Restoring model weights from the end of the best epoch: 5.

# %%
lr_reducer, checkpoint, early_stopping = Callbacks('CNN2DGenderU')
# Huấn luyện
historyCNN2DGenderU = CNN2DGenderU.fit(
    Xg_train_2D,  # Dữ liệu huấn luyện tăng cường
    yg_train_cat,  # Nhãn huấn luyện dạng one-hot
    epochs=200, 
    batch_size=64,  
    validation_data=(Xg_dev_2D, yg_dev_cat),  # Dữ liệu validation
    callbacks=[lr_reducer, checkpoint, early_stopping],  # Sử dụng các callback
    verbose=1  # Hiển thị tiến trình huấn luyện
)
# Out:
# Epoch 1/200
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7991 - loss: 0.6471
# Epoch 1: val_accuracy improved from -inf to 0.49837, saving model to best_CNN2DGenderU.keras
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 12s 35ms/step - accuracy: 0.7994 - loss: 0.6464 - val_accuracy: 0.4984 - val_loss: 0.8762 - learning_rate: 2.1682e-04
# Epoch 2/200
# 145/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9106 - loss: 0.4079
# Epoch 2: val_accuracy improved from 0.49837 to 0.71084, saving model to best_CNN2DGenderU.keras
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9111 - loss: 0.4064 - val_accuracy: 0.7108 - val_loss: 0.8589 - learning_rate: 2.1682e-04
# Epoch 3/200
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9305 - loss: 0.3534
# Epoch 3: val_accuracy improved from 0.71084 to 0.78884, saving model to best_CNN2DGenderU.keras
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9305 - loss: 0.3533 - val_accuracy: 0.7888 - val_loss: 0.7593 - learning_rate: 2.1682e-04
# Epoch 4/200
# 145/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9441 - loss: 0.3228
# Epoch 4: val_accuracy improved from 0.78884 to 0.82637, saving model to best_CNN2DGenderU.keras
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9439 - loss: 0.3227 - val_accuracy: 0.8264 - val_loss: 0.6275 - learning_rate: 2.1682e-04
# Epoch 5/200
# 144/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9486 - loss: 0.2977
# Epoch 5: val_accuracy improved from 0.82637 to 0.83616, saving model to best_CNN2DGenderU.keras
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9485 - loss: 0.2979 - val_accuracy: 0.8362 - val_loss: 0.5971 - learning_rate: 2.1682e-04
# Epoch 6/200
# 145/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9505 - loss: 0.2867
# Epoch 6: val_accuracy did not improve from 0.83616
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9505 - loss: 0.2870 - val_accuracy: 0.8283 - val_loss: 0.7056 - learning_rate: 2.1682e-04
# Epoch 7/200
# 145/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9557 - loss: 0.2727
# Epoch 7: val_accuracy did not improve from 0.83616
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9556 - loss: 0.2726 - val_accuracy: 0.8319 - val_loss: 0.7132 - learning_rate: 2.1682e-04
# Epoch 8/200
# 145/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9618 - loss: 0.2552
# Epoch 8: val_accuracy did not improve from 0.83616
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9616 - loss: 0.2554 - val_accuracy: 0.8336 - val_loss: 0.6890 - learning_rate: 2.1682e-04
# Epoch 9/200
# 145/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9679 - loss: 0.2364
# Epoch 9: val_accuracy improved from 0.83616 to 0.83910, saving model to best_CNN2DGenderU.keras
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9676 - loss: 0.2371 - val_accuracy: 0.8391 - val_loss: 0.6979 - learning_rate: 2.1682e-04
# Epoch 10/200
# 145/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9723 - loss: 0.2288
# Epoch 10: val_accuracy did not improve from 0.83910
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9721 - loss: 0.2290 - val_accuracy: 0.8352 - val_loss: 0.6957 - learning_rate: 2.1682e-04
# Epoch 11/200
# 145/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9701 - loss: 0.2223
# Epoch 11: val_accuracy did not improve from 0.83910
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9701 - loss: 0.2222 - val_accuracy: 0.8270 - val_loss: 0.7407 - learning_rate: 2.1682e-04
# Epoch 12/200
# 155/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9752 - loss: 0.2086
# Epoch 12: val_accuracy did not improve from 0.83910
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9752 - loss: 0.2087 - val_accuracy: 0.8293 - val_loss: 0.6826 - learning_rate: 2.1682e-04
# Epoch 13/200
# 145/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9761 - loss: 0.2020
# Epoch 13: ReduceLROnPlateau reducing learning rate to 6.504676857730373e-05.
#
# Epoch 13: val_accuracy did not improve from 0.83910
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9761 - loss: 0.2020 - val_accuracy: 0.8332 - val_loss: 0.7789 - learning_rate: 2.1682e-04
# Epoch 14/200
# 144/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9758 - loss: 0.2017
# Epoch 14: val_accuracy improved from 0.83910 to 0.84856, saving model to best_CNN2DGenderU.keras
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9763 - loss: 0.2005 - val_accuracy: 0.8486 - val_loss: 0.6293 - learning_rate: 6.5047e-05
# Epoch 15/200
# 145/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9896 - loss: 0.1695
# Epoch 15: val_accuracy did not improve from 0.84856
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9893 - loss: 0.1699 - val_accuracy: 0.8401 - val_loss: 0.7408 - learning_rate: 6.5047e-05
# Epoch 16/200
# 145/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9906 - loss: 0.1630
# Epoch 16: val_accuracy did not improve from 0.84856
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9905 - loss: 0.1631 - val_accuracy: 0.8339 - val_loss: 0.7621 - learning_rate: 6.5047e-05
# Epoch 17/200
# 145/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9900 - loss: 0.1629
# Epoch 17: val_accuracy did not improve from 0.84856
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9901 - loss: 0.1626 - val_accuracy: 0.8424 - val_loss: 0.7251 - learning_rate: 6.5047e-05
# Epoch 18/200
# 145/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9918 - loss: 0.1569
# Epoch 18: val_accuracy did not improve from 0.84856
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9918 - loss: 0.1571 - val_accuracy: 0.8411 - val_loss: 0.7425 - learning_rate: 6.5047e-05
# Epoch 19/200
# 145/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9937 - loss: 0.1519
# Epoch 19: val_accuracy did not improve from 0.84856
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9936 - loss: 0.1520 - val_accuracy: 0.8407 - val_loss: 0.7270 - learning_rate: 6.5047e-05
# Epoch 20/200
# 154/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9938 - loss: 0.1488
# Epoch 20: val_accuracy did not improve from 0.84856
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9938 - loss: 0.1488 - val_accuracy: 0.8437 - val_loss: 0.7325 - learning_rate: 6.5047e-05
# Epoch 21/200
# 145/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9943 - loss: 0.1482
# Epoch 21: ReduceLROnPlateau reducing learning rate to 1.9514031009748578e-05.
#
# Epoch 21: val_accuracy did not improve from 0.84856
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9944 - loss: 0.1481 - val_accuracy: 0.8443 - val_loss: 0.7403 - learning_rate: 6.5047e-05
# Epoch 22/200
# 145/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9971 - loss: 0.1416
# Epoch 22: val_accuracy did not improve from 0.84856
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9970 - loss: 0.1417 - val_accuracy: 0.8420 - val_loss: 0.7909 - learning_rate: 1.9514e-05
# Epoch 23/200
# 145/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9949 - loss: 0.1421
# Epoch 23: val_accuracy did not improve from 0.84856
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9949 - loss: 0.1421 - val_accuracy: 0.8430 - val_loss: 0.7909 - learning_rate: 1.9514e-05
# Epoch 24/200
# 145/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9966 - loss: 0.1384
# Epoch 24: val_accuracy did not improve from 0.84856
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9965 - loss: 0.1385 - val_accuracy: 0.8407 - val_loss: 0.8183 - learning_rate: 1.9514e-05
# Epoch 25/200
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9971 - loss: 0.1371
# Epoch 25: val_accuracy did not improve from 0.84856
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9971 - loss: 0.1371 - val_accuracy: 0.8427 - val_loss: 0.8130 - learning_rate: 1.9514e-05
# Epoch 26/200
# 144/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9951 - loss: 0.1380
# Epoch 26: val_accuracy did not improve from 0.84856
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9952 - loss: 0.1379 - val_accuracy: 0.8417 - val_loss: 0.8153 - learning_rate: 1.9514e-05
# Epoch 27/200
# 145/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9961 - loss: 0.1370
# Epoch 27: val_accuracy did not improve from 0.84856
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9961 - loss: 0.1370 - val_accuracy: 0.8424 - val_loss: 0.7970 - learning_rate: 1.9514e-05
# Epoch 28/200
# 144/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9975 - loss: 0.1328
# Epoch 28: val_accuracy did not improve from 0.84856
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9975 - loss: 0.1328 - val_accuracy: 0.8398 - val_loss: 0.8470 - learning_rate: 1.9514e-05
# Epoch 29/200
# 157/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9980 - loss: 0.1318
# Epoch 29: ReduceLROnPlateau reducing learning rate to 5.854209302924574e-06.
#
# Epoch 29: val_accuracy did not improve from 0.84856
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9980 - loss: 0.1318 - val_accuracy: 0.8391 - val_loss: 0.8460 - learning_rate: 1.9514e-05
# Epoch 30/200
# 145/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9965 - loss: 0.1352
# Epoch 30: val_accuracy did not improve from 0.84856
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9965 - loss: 0.1351 - val_accuracy: 0.8401 - val_loss: 0.8427 - learning_rate: 5.8542e-06
# Epoch 31/200
# 145/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9936 - loss: 0.1400
# Epoch 31: val_accuracy did not improve from 0.84856
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9938 - loss: 0.1396 - val_accuracy: 0.8388 - val_loss: 0.8599 - learning_rate: 5.8542e-06
# Epoch 32/200
# 145/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9970 - loss: 0.1338
# Epoch 32: val_accuracy did not improve from 0.84856
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9971 - loss: 0.1336 - val_accuracy: 0.8394 - val_loss: 0.8671 - learning_rate: 5.8542e-06
# Epoch 33/200
# 145/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9977 - loss: 0.1308
# Epoch 33: val_accuracy did not improve from 0.84856
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9977 - loss: 0.1310 - val_accuracy: 0.8378 - val_loss: 0.8585 - learning_rate: 5.8542e-06
# Epoch 34/200
# 145/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9979 - loss: 0.1318
# Epoch 34: val_accuracy did not improve from 0.84856
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9979 - loss: 0.1317 - val_accuracy: 0.8394 - val_loss: 0.8569 - learning_rate: 5.8542e-06
# Epoch 34: early stopping
# Restoring model weights from the end of the best epoch: 14.

# %%
CNN2DGenderU.summary()
CNN2DRegionU.summary()
CNN2DGenderU.save('gender_model_normal_update.keras')
CNN2DRegionU.save('region_model_normal_update.keras')
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_2 (Conv2D)               │ (None, 7, 10, 96)      │         2,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 7, 10, 96)      │           384 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 7, 10, 96)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 7, 10, 64)      │       153,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 7, 10, 64)      │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 7, 10, 64)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 4480)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 96)             │       430,176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 96)             │           384 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 96)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 16)             │         1,552 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 16)             │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 2)              │            34 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,765,944 (6.74 MB)
#  Trainable params: 588,466 (2.24 MB)
#  Non-trainable params: 544 (2.12 KB)
#  Optimizer params: 1,176,934 (4.49 MB)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 7, 10, 96)      │         2,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 7, 10, 96)      │           384 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 7, 10, 96)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 7, 10, 64)      │       153,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 7, 10, 64)      │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 7, 10, 64)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 4480)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 96)             │       430,176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 96)             │           384 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 96)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 16)             │         1,552 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 16)             │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 3)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,765,995 (6.74 MB)
#  Trainable params: 588,483 (2.24 MB)
#  Non-trainable params: 544 (2.12 KB)
#  Optimizer params: 1,176,968 (4.49 MB)

# %%
Evaluateandlogperformance(CNN2DRegionU, historyCNN2DRegionU, Xr_test_2D, yr_test_cat, 'CNN2DRegionU', detail = False)
Evaluateandlogperformance(CNN2DGenderU, historyCNN2DGenderU, Xg_test_2D, yg_test_cat, 'CNN2DGenderU', detail = False)
# Out:
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4944 - loss: 1.2440
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9161 - loss: 0.3972

# %%
compute_confusion_matrix(CNN2DRegionU, Xr_test_2D, yr_test_cat, 'CNN2DRegionU', 3)
compute_confusion_matrix(CNN2DGenderU, Xg_test_2D, yg_test_cat, 'CNN2DGenderU', 2)
# Out:
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.61      0.52      0.57      1252
#            1       0.49      0.56      0.52       848
#            2       0.48      0.52      0.50       852
#
#     accuracy                           0.53      2952
#    macro avg       0.53      0.53      0.53      2952
# weighted avg       0.54      0.53      0.53      2952
#
#
# Detailed Metrics by Class:
#
# Class 0:
# Precision: 0.6142
# Recall: 0.5240
# F1-score: 0.5655
#
# Class 1:
# Precision: 0.4918
# Recall: 0.5625
# F1-score: 0.5248
#
# Class 2:
# Precision: 0.4803
# Recall: 0.5153
# F1-score: 0.4972
#
# Overall Metrics:
# Average Precision: 0.5404
# Average Recall: 0.5325
# Average F1-score: 0.5341
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94      1967
#            1       0.94      0.81      0.87       985
#
#     accuracy                           0.92      2952
#    macro avg       0.92      0.89      0.91      2952
# weighted avg       0.92      0.92      0.92      2952
#
#
# Detailed Metrics by Class:
#
# Class 0:
# Precision: 0.9110
# Recall: 0.9736
# F1-score: 0.9413
#
# Class 1:
# Precision: 0.9388
# Recall: 0.8102
# F1-score: 0.8698
#
# Overall Metrics:
# Average Precision: 0.9203
# Average Recall: 0.9190
# Average F1-score: 0.9174

# %% [markdown]
# # Keras Tuner

# %%
# Hàm xây dựng mô hình với Keras Tuner
def build_region(hp):
    model = Sequential()

    # First Conv2D layer
    filters_0 = hp.Int('filters_0', min_value=16, max_value=96, step=16)
    kernel_size_0 = hp.Choice('kernel_size_0', values=[3, 5])
    l2_conv_0 = hp.Float('l2_conv_0', min_value=1e-4, max_value=1e-2, sampling='log')
    
    model.add(Conv2D(
        filters=filters_0,
        kernel_size=kernel_size_0,
        strides=1,
        padding='same',
        activation='relu',
        input_shape=(7, 10, 1),
        kernel_regularizer=l2(l2_conv_0)
    ))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(
        pool_size=hp.Choice('pool_size_0', values=[2, 3]),
        strides=1,
        padding='same'
    ))

    # Second Conv2D layer (tùy chọn)
    include_conv1 = hp.Boolean('include_conv1')
    if include_conv1:
        filters_1 = hp.Int('filters_1', min_value=16, max_value=64, step=16)
        kernel_size_1 = hp.Choice('kernel_size_1', values=[3, 5])
        l2_conv_1 = hp.Float('l2_conv_1', min_value=1e-4, max_value=1e-2, sampling='log')
        
        model.add(Conv2D(
            filters=filters_1,
            kernel_size=kernel_size_1,
            strides=1,
            padding='same',
            activation='relu',
            kernel_regularizer=l2(l2_conv_1)
        ))
        model.add(BatchNormalization())

    # Dropout sau Conv layers
    dropout_conv = hp.Float('dropout_conv', min_value=0.0, max_value=0.5, step=0.1)
    model.add(Dropout(rate=dropout_conv))

    # Flatten
    model.add(Flatten())

    # First Dense layer (tùy chọn)
    include_dense0 = hp.Boolean('include_dense0')
    if include_dense0:
        units_0 = hp.Int('units_0', min_value=16, max_value=96, step=16)
        l2_dense_0 = hp.Float('l2_dense_0', min_value=1e-4, max_value=1e-2, sampling='log')
        dropout_dense_0 = hp.Float('dropout_dense_0', min_value=0.0, max_value=0.5, step=0.1)
        
        model.add(Dense(
            units=units_0,
            activation='relu',
            kernel_regularizer=l2(l2_dense_0)
        ))
        model.add(BatchNormalization())
        model.add(Dropout(rate=dropout_dense_0))

    # Second Dense layer
    units_1 = hp.Int('units_1', min_value=8, max_value=32, step=8)
    l2_dense_1 = hp.Float('l2_dense_1', min_value=1e-4, max_value=1e-2, sampling='log')
    dropout_dense_1 = hp.Float('dropout_dense_1', min_value=0.0, max_value=0.5, step=0.1)
    
    model.add(Dense(
        units=units_1,
        activation='relu',
        kernel_regularizer=l2(l2_dense_1)
    ))
    model.add(BatchNormalization())
    model.add(Dropout(rate=dropout_dense_1))

    # Output layer (3 lớp cho region)
    model.add(Dense(3, activation='softmax'))

    # Compile model
    learning_rate = hp.Float('learning_rate', min_value=1e-4, max_value=1e-2, sampling='log')
    model.compile(
        optimizer=Adam(learning_rate=learning_rate),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )
    
    return model
    
# EarlyStopping
early_stopping = EarlyStopping(
    monitor='val_accuracy',
    patience=10,
    restore_best_weights=True,
    mode='max',
    verbose=1
)

tuner_regionU = kt.Hyperband(
    build_region,
    objective=kt.Objective("val_accuracy", direction="max"),
    max_epochs=10,
    factor=3,
    hyperband_iterations=2,
    directory='tuner_dir2',
    project_name='cnn2d_region_hyperband'
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Hàm xây dựng mô hình với Keras Tuner
def build_gender(hp):
    model = Sequential()

    # First Conv2D layer
    filters_0 = hp.Int('filters_0', min_value=16, max_value=96, step=16)
    kernel_size_0 = hp.Choice('kernel_size_0', values=[3, 5])
    l2_conv_0 = hp.Float('l2_conv_0', min_value=1e-4, max_value=1e-2, sampling='log')
    
    model.add(Conv2D(
        filters=filters_0,
        kernel_size=kernel_size_0,
        strides=1,
        padding='same',
        activation='relu',
        input_shape=(7, 10, 1),
        kernel_regularizer=l2(l2_conv_0)
    ))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(
        pool_size=hp.Choice('pool_size_0', values=[2, 3]),
        strides=1,
        padding='same'
    ))

    # Second Conv2D layer (tùy chọn)
    include_conv1 = hp.Boolean('include_conv1')
    if include_conv1:
        filters_1 = hp.Int('filters_1', min_value=16, max_value=64, step=16)
        kernel_size_1 = hp.Choice('kernel_size_1', values=[3, 5])
        l2_conv_1 = hp.Float('l2_conv_1', min_value=1e-4, max_value=1e-2, sampling='log')
        
        model.add(Conv2D(
            filters=filters_1,
            kernel_size=kernel_size_1,
            strides=1,
            padding='same',
            activation='relu',
            kernel_regularizer=l2(l2_conv_1)
        ))
        model.add(BatchNormalization())

    # Dropout sau Conv layers
    dropout_conv = hp.Float('dropout_conv', min_value=0.0, max_value=0.5, step=0.1)
    model.add(Dropout(rate=dropout_conv))

    # Flatten
    model.add(Flatten())

    # First Dense layer (tùy chọn)
    include_dense0 = hp.Boolean('include_dense0')
    if include_dense0:
        units_0 = hp.Int('units_0', min_value=16, max_value=96, step=16)
        l2_dense_0 = hp.Float('l2_dense_0', min_value=1e-4, max_value=1e-2, sampling='log')
        dropout_dense_0 = hp.Float('dropout_dense_0', min_value=0.0, max_value=0.5, step=0.1)
        
        model.add(Dense(
            units=units_0,
            activation='relu',
            kernel_regularizer=l2(l2_dense_0)
        ))
        model.add(BatchNormalization())
        model.add(Dropout(rate=dropout_dense_0))

    # Second Dense layer
    units_1 = hp.Int('units_1', min_value=8, max_value=32, step=8)
    l2_dense_1 = hp.Float('l2_dense_1', min_value=1e-4, max_value=1e-2, sampling='log')
    dropout_dense_1 = hp.Float('dropout_dense_1', min_value=0.0, max_value=0.5, step=0.1)
    
    model.add(Dense(
        units=units_1,
        activation='relu',
        kernel_regularizer=l2(l2_dense_1)
    ))
    model.add(BatchNormalization())
    model.add(Dropout(rate=dropout_dense_1))

    # Output layer (3 lớp cho region)
    model.add(Dense(2, activation='softmax'))

    # Compile model
    learning_rate = hp.Float('learning_rate', min_value=1e-4, max_value=1e-2, sampling='log')
    model.compile(
        optimizer=Adam(learning_rate=learning_rate),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )
    
    return model


# EarlyStopping
early_stopping = EarlyStopping(
    monitor='val_accuracy',
    patience=10,
    restore_best_weights=True,
    mode='max',
    verbose=1
)

tuner_genderU = kt.Hyperband(
    build_gender,
    objective=kt.Objective("val_accuracy", direction="max"),
    max_epochs=10,
    factor=3,
    hyperband_iterations=2,
    directory='tuner_dir2',
    project_name='cnn2d_gender_hyperband'
)

# %%
# Tìm kiếm mô hình
tuner_regionU.search(
    Xr_train_2D, yr_train_cat, 
    epochs=100, batch_size=64,
    validation_data=(Xr_dev_2D, yr_dev_cat), 
    callbacks=[early_stopping], verbose=2 
)
# Out:
# Trial 60 Complete [00h 00m 20s]
# val_accuracy: 0.5078328847885132
#
# Best val_accuracy So Far: 0.5489556193351746
# Total elapsed time: 00h 12m 39s

# %% [markdown]
# Trial 60 Complete [00h 00m 14s]
# val_accuracy: 0.9440069794654846
#
# Best val_accuracy So Far: 0.9816272854804993
# Total elapsed time: 00h 13m 37s

# %%
# Lấy mô hình tốt nhất
best_model = tuner_regionU.get_best_models(num_models=1)[0]
best_hyperparameters = tuner_regionU.get_best_hyperparameters(num_trials=1)[0]

# In thông tin mô hình tốt nhất
print("Best hyperparameters:")
for param, value in best_hyperparameters.values.items():
    print(f"{param}: {value}")
best_model.summary()

# Đánh giá trên tập test
test_loss, test_accuracy = best_model.evaluate(Xr_test_2D, yr_test_cat)
print("Test accuracy:", test_accuracy)

# Lưu mô hình nhẹ nhất
best_model.save("cnn2d_regionU_light_hyperband.keras")
# Out:
# Best hyperparameters:
# filters_0: 16
# kernel_size_0: 3
# l2_conv_0: 0.0007940243226892147
# pool_size_0: 3
# include_conv1: True
# dropout_conv: 0.1
# include_dense0: True
# units_1: 24
# l2_dense_1: 0.00022289520939503473
# dropout_dense_1: 0.2
# learning_rate: 0.0006293796738183739
# units_0: 32
# l2_dense_0: 0.0006304776593119199
# dropout_dense_0: 0.2
# filters_1: 32
# kernel_size_1: 5
# l2_conv_1: 0.0019474633087413814
# tuner/epochs: 10
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 7, 10, 16)      │           160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 7, 10, 16)      │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 7, 10, 16)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 7, 10, 32)      │        12,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 7, 10, 32)      │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 7, 10, 32)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2240)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │        71,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 24)             │           792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 24)             │            96 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 24)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 3)              │            75 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 85,987 (335.89 KB)
#  Trainable params: 85,779 (335.07 KB)
#  Non-trainable params: 208 (832.00 B)
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5027 - loss: 1.2331
# Test accuracy: 0.49661245942115784

# %% [markdown]
# Best hyperparameters:
# filters_0: 80
# kernel_size_0: 5
# l2_conv_0: 0.0009407757563332102
# pool_size_0: 2
# include_conv1: True
# dropout_conv: 0.0
# include_dense0: True
# units_1: 8
# l2_dense_1: 0.0007383436520516292
# dropout_dense_1: 0.2
# learning_rate: 0.0005623425672652072
# filters_1: 32
# kernel_size_1: 5
# l2_conv_1: 0.0006007648451425429
# units_0: 80
# l2_dense_0: 0.006952832162532451
# dropout_dense_0: 0.1
# tuner/epochs: 10
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0

# %%
# Tìm kiếm mô hình
tuner_genderU.search(
    Xg_train_2D, yg_train_cat, 
    epochs=100, batch_size=64,
    validation_data=(Xg_dev_2D, yg_dev_cat), 
    callbacks=[early_stopping], verbose=2 
)
# Out:
# Trial 60 Complete [00h 00m 22s]
# val_accuracy: 0.8469321131706238
#
# Best val_accuracy So Far: 0.8616188168525696
# Total elapsed time: 00h 13m 51s

# %% [markdown]
# Trial 60 Complete [00h 00m 24s]
# val_accuracy: 0.9503105878829956
#
# Best val_accuracy So Far: 0.9856665134429932
# Total elapsed time: 00h 15m 31s

# %%
# Lấy mô hình tốt nhất
best_model = tuner_genderU.get_best_models(num_models=1)[0]
best_hyperparameters = tuner_genderU.get_best_hyperparameters(num_trials=1)[0]

# In thông tin mô hình tốt nhất
print("Best hyperparameters:")
for param, value in best_hyperparameters.values.items():
    print(f"{param}: {value}")
best_model.summary()

# Đánh giá trên tập test
test_loss, test_accuracy = best_model.evaluate(Xg_test_2D, yg_test_cat)
print("Test accuracy:", test_accuracy)

# Lưu mô hình nhẹ nhất
best_model.save("cnn2d_genderU_light_hyperband.keras")
# Out:
# Best hyperparameters:
# filters_0: 32
# kernel_size_0: 3
# l2_conv_0: 0.001426440952221173
# pool_size_0: 2
# include_conv1: False
# dropout_conv: 0.0
# include_dense0: False
# units_1: 24
# l2_dense_1: 0.0015463362595452633
# dropout_dense_1: 0.2
# learning_rate: 0.001592797574789083
# units_0: 64
# l2_dense_0: 0.002939368265865483
# dropout_dense_0: 0.0
# tuner/epochs: 10
# tuner/initial_epoch: 4
# tuner/bracket: 2
# tuner/round: 2
# tuner/trial_id: 0012
# filters_1: 16
# kernel_size_1: 5
# l2_conv_1: 0.00043385098721905575
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 7, 10, 32)      │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 7, 10, 32)      │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 7, 10, 32)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 7, 10, 32)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2240)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 24)             │        53,784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 24)             │            96 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 24)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 2)              │            50 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 54,378 (212.41 KB)
#  Trainable params: 54,266 (211.98 KB)
#  Non-trainable params: 112 (448.00 B)
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8954 - loss: 0.3088
# Test accuracy: 0.8976964950561523

# %% [markdown]
# Best hyperparameters:
# filters_0: 48
# kernel_size_0: 5
# l2_conv_0: 0.00013018329843895806
# pool_size_0: 2
# include_conv1: True
# dropout_conv: 0.0
# include_dense0: True
# units_1: 24
# l2_dense_1: 0.003451000688272909
# dropout_dense_1: 0.1
# learning_rate: 0.0004257494904478956
# units_0: 48
# l2_dense_0: 0.0004731779586917222
# dropout_dense_0: 0.0
# filters_1: 16
# kernel_size_1: 3
# l2_conv_1: 0.0002666980361332198
# tuner/epochs: 10
# tuner/initial_epoch: 4
# tuner/bracket: 1
# tuner/round: 1
# tuner/trial_id: 0049

# %% [markdown]
# # Apply hyperparameters

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, BatchNormalization, MaxPooling2D, Dropout, Flatten, Dense
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam

# Xây dựng mô hình CNN2DRegionUHyper với các siêu tham số tốt nhất (mới)
CNN2DRegionUHyper = Sequential()

# First Conv2D layer
CNN2DRegionUHyper.add(Conv2D(
    filters=80,  # filters_0
    kernel_size=5,  # kernel_size_0
    strides=1,
    padding='same',
    activation='relu',
    input_shape=(7, 10, 1),
    kernel_regularizer=l2(0.0009407757563332102)  # l2_conv_0
))
CNN2DRegionUHyper.add(BatchNormalization())
CNN2DRegionUHyper.add(MaxPooling2D(
    pool_size=2,  # pool_size_0
    strides=1,
    padding='same'
))

# Second Conv2D layer (include_conv1 = True)
CNN2DRegionUHyper.add(Conv2D(
    filters=32,  # filters_1
    kernel_size=5,  # kernel_size_1
    strides=1,
    padding='same',
    activation='relu',
    kernel_regularizer=l2(0.0006007648451425429)  # l2_conv_1
))
CNN2DRegionUHyper.add(BatchNormalization())

# Dropout after Conv2D layers
CNN2DRegionUHyper.add(Dropout(rate=0.0))  # dropout_conv

# Flatten layer
CNN2DRegionUHyper.add(Flatten())

# First Dense layer (include_dense0 = True)
CNN2DRegionUHyper.add(Dense(
    units=80,  # units_0
    activation='relu',
    kernel_regularizer=l2(0.006952832162532451)  # l2_dense_0
))
CNN2DRegionUHyper.add(BatchNormalization())
CNN2DRegionUHyper.add(Dropout(rate=0.1))  # dropout_dense_0

# Second Dense layer
CNN2DRegionUHyper.add(Dense(
    units=8,  # units_1
    activation='relu',
    kernel_regularizer=l2(0.0007383436520516292)  # l2_dense_1
))
CNN2DRegionUHyper.add(BatchNormalization())
CNN2DRegionUHyper.add(Dropout(rate=0.2))  # dropout_dense_1

# Output layer
CNN2DRegionUHyper.add(Dense(3, activation='softmax'))  # 3 lớp: Southern, Central, Northern

# Compile the model
CNN2DRegionUHyper.compile(
    optimizer=Adam(learning_rate=0.0005623425672652072),  # learning_rate
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Display model summary
CNN2DRegionUHyper.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_1 (Conv2D)               │ (None, 7, 10, 80)      │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 7, 10, 80)      │           320 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 7, 10, 80)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 7, 10, 32)      │        64,032 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 7, 10, 32)      │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 7, 10, 32)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 2240)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 80)             │       179,280 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 80)             │           320 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 80)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 8)              │           648 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 8)              │            32 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 8)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 3)              │            27 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 246,867 (964.32 KB)
#  Trainable params: 246,467 (962.76 KB)
#  Non-trainable params: 400 (1.56 KB)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, BatchNormalization, MaxPooling2D, Dropout, Flatten, Dense
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam

# Xây dựng mô hình CNN2DGenderUHyper với các siêu tham số mới
CNN2DGenderUHyper = Sequential()

# First Conv2D layer
CNN2DGenderUHyper.add(Conv2D(
    filters=48,  # filters_0
    kernel_size=5,  # kernel_size_0
    strides=1,
    padding='same',
    activation='relu',
    input_shape=(7, 10, 1),
    kernel_regularizer=l2(0.00013018329843895806)  # l2_conv_0
))
CNN2DGenderUHyper.add(BatchNormalization())
CNN2DGenderUHyper.add(MaxPooling2D(
    pool_size=2,  # pool_size_0
    strides=1,
    padding='same'
))

# Second Conv2D layer (include_conv1 = True)
CNN2DGenderUHyper.add(Conv2D(
    filters=16,  # filters_1
    kernel_size=3,  # kernel_size_1
    strides=1,
    padding='same',
    activation='relu',
    kernel_regularizer=l2(0.0002666980361332198)  # l2_conv_1
))
CNN2DGenderUHyper.add(BatchNormalization())

# Dropout after Conv2D layers
CNN2DGenderUHyper.add(Dropout(rate=0.0))  # dropout_conv

# Flatten layer
CNN2DGenderUHyper.add(Flatten())

# First Dense layer (include_dense0 = True)
CNN2DGenderUHyper.add(Dense(
    units=48,  # units_0
    activation='relu',
    kernel_regularizer=l2(0.0004731779586917222)  # l2_dense_0
))
CNN2DGenderUHyper.add(BatchNormalization())
CNN2DGenderUHyper.add(Dropout(rate=0.0))  # dropout_dense_0

# Second Dense layer
CNN2DGenderUHyper.add(Dense(
    units=24,  # units_1
    activation='relu',
    kernel_regularizer=l2(0.003451000688272909)  # l2_dense_1
))
CNN2DGenderUHyper.add(BatchNormalization())
CNN2DGenderUHyper.add(Dropout(rate=0.1))  # dropout_dense_1

# Output layer
CNN2DGenderUHyper.add(Dense(2, activation='softmax'))  # 2 lớp: Male, Female

# Compile the model
CNN2DGenderUHyper.compile(
    optimizer=Adam(learning_rate=0.0004257494904478956),  # learning_rate
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Hiển thị cấu trúc mô hình
CNN2DGenderUHyper.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)               │ (None, 7, 10, 48)      │         1,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 7, 10, 48)      │           192 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 7, 10, 48)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 7, 10, 16)      │         6,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 7, 10, 16)      │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 7, 10, 16)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 1120)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 48)             │        53,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 48)             │           192 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 48)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 24)             │         1,176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 24)             │            96 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 24)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 2)              │            50 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 63,754 (249.04 KB)
#  Trainable params: 63,482 (247.98 KB)
#  Non-trainable params: 272 (1.06 KB)

# %%
lr_reducer, checkpoint, early_stopping = Callbacks('CNN2DRegionUHyper')
# Huấn luyện
historyCNN2DRegionUHyper = CNN2DRegionUHyper.fit(
    Xr_train_2D,  # Dữ liệu huấn luyện tăng cường
    yr_train_cat,  # Nhãn huấn luyện dạng one-hot
    epochs=200, 
    batch_size=64,  
    validation_data=(Xr_dev_2D, yr_dev_cat),  # Dữ liệu validation
    callbacks=[lr_reducer, checkpoint, early_stopping],  # Sử dụng các callback
    verbose=1  # Hiển thị tiến trình huấn luyện
)
# Out:
# Epoch 1/200
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4876 - loss: 2.1109
# Epoch 1: val_accuracy improved from -inf to 0.40503, saving model to best_CNN2DRegionUHyper.keras
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 11s 33ms/step - accuracy: 0.4880 - loss: 2.1097 - val_accuracy: 0.4050 - val_loss: 1.8655 - learning_rate: 5.6234e-04
# Epoch 2/200
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6691 - loss: 1.4707
# Epoch 2: val_accuracy improved from 0.40503 to 0.44093, saving model to best_CNN2DRegionUHyper.keras
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6692 - loss: 1.4701 - val_accuracy: 0.4409 - val_loss: 1.6047 - learning_rate: 5.6234e-04
# Epoch 3/200
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7416 - loss: 1.1168
# Epoch 3: val_accuracy improved from 0.44093 to 0.51664, saving model to best_CNN2DRegionUHyper.keras
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7416 - loss: 1.1166 - val_accuracy: 0.5166 - val_loss: 1.4247 - learning_rate: 5.6234e-04
# Epoch 4/200
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7767 - loss: 0.9091
# Epoch 4: val_accuracy did not improve from 0.51664
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7767 - loss: 0.9089 - val_accuracy: 0.5082 - val_loss: 1.4971 - learning_rate: 5.6234e-04
# Epoch 5/200
# 157/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8019 - loss: 0.7770
# Epoch 5: val_accuracy did not improve from 0.51664
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8019 - loss: 0.7768 - val_accuracy: 0.4961 - val_loss: 1.4705 - learning_rate: 5.6234e-04
# Epoch 6/200
# 157/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8335 - loss: 0.6604
# Epoch 6: val_accuracy did not improve from 0.51664
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8334 - loss: 0.6605 - val_accuracy: 0.4765 - val_loss: 1.5610 - learning_rate: 5.6234e-04
# Epoch 7/200
# 142/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8423 - loss: 0.6142
# Epoch 7: val_accuracy improved from 0.51664 to 0.52219, saving model to best_CNN2DRegionUHyper.keras
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8414 - loss: 0.6159 - val_accuracy: 0.5222 - val_loss: 1.5831 - learning_rate: 5.6234e-04
# Epoch 8/200
# 157/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8465 - loss: 0.6037
# Epoch 8: val_accuracy did not improve from 0.52219
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8466 - loss: 0.6036 - val_accuracy: 0.4925 - val_loss: 1.6159 - learning_rate: 5.6234e-04
# Epoch 9/200
# 155/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8789 - loss: 0.5152
# Epoch 9: val_accuracy did not improve from 0.52219
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8788 - loss: 0.5156 - val_accuracy: 0.5111 - val_loss: 1.5480 - learning_rate: 5.6234e-04
# Epoch 10/200
# 158/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8859 - loss: 0.4951
# Epoch 10: val_accuracy did not improve from 0.52219
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8858 - loss: 0.4953 - val_accuracy: 0.4820 - val_loss: 1.6412 - learning_rate: 5.6234e-04
# Epoch 11/200
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8907 - loss: 0.4832
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.00016870277468115092.
#
# Epoch 11: val_accuracy did not improve from 0.52219
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8907 - loss: 0.4832 - val_accuracy: 0.5000 - val_loss: 1.6262 - learning_rate: 5.6234e-04
# Epoch 12/200
# 156/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9285 - loss: 0.4065
# Epoch 12: val_accuracy did not improve from 0.52219
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9288 - loss: 0.4057 - val_accuracy: 0.5108 - val_loss: 1.6428 - learning_rate: 1.6870e-04
# Epoch 13/200
# 158/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9577 - loss: 0.3147
# Epoch 13: val_accuracy did not improve from 0.52219
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9577 - loss: 0.3146 - val_accuracy: 0.5026 - val_loss: 1.7251 - learning_rate: 1.6870e-04
# Epoch 14/200
# 157/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9692 - loss: 0.2732
# Epoch 14: val_accuracy did not improve from 0.52219
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9692 - loss: 0.2731 - val_accuracy: 0.5199 - val_loss: 1.7105 - learning_rate: 1.6870e-04
# Epoch 15/200
# 158/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9756 - loss: 0.2416
# Epoch 15: val_accuracy did not improve from 0.52219
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9755 - loss: 0.2416 - val_accuracy: 0.5189 - val_loss: 1.7392 - learning_rate: 1.6870e-04
# Epoch 16/200
# 157/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9789 - loss: 0.2224
# Epoch 16: val_accuracy did not improve from 0.52219
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9789 - loss: 0.2223 - val_accuracy: 0.5124 - val_loss: 1.8135 - learning_rate: 1.6870e-04
# Epoch 17/200
# 148/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9860 - loss: 0.2001
# Epoch 17: val_accuracy did not improve from 0.52219
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9859 - loss: 0.2000 - val_accuracy: 0.5153 - val_loss: 1.8865 - learning_rate: 1.6870e-04
# Epoch 18/200
# 156/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9857 - loss: 0.1885
# Epoch 18: val_accuracy improved from 0.52219 to 0.53003, saving model to best_CNN2DRegionUHyper.keras
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9857 - loss: 0.1885 - val_accuracy: 0.5300 - val_loss: 1.8542 - learning_rate: 1.6870e-04
# Epoch 19/200
# 158/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9877 - loss: 0.1792
# Epoch 19: ReduceLROnPlateau reducing learning rate to 5.0610830658115444e-05.
#
# Epoch 19: val_accuracy did not improve from 0.53003
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9877 - loss: 0.1792 - val_accuracy: 0.5261 - val_loss: 1.9377 - learning_rate: 1.6870e-04
# Epoch 20/200
# 155/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9909 - loss: 0.1635
# Epoch 20: val_accuracy did not improve from 0.53003
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9909 - loss: 0.1634 - val_accuracy: 0.5238 - val_loss: 1.9666 - learning_rate: 5.0611e-05
# Epoch 21/200
# 158/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9934 - loss: 0.1549
# Epoch 21: val_accuracy did not improve from 0.53003
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9934 - loss: 0.1548 - val_accuracy: 0.5180 - val_loss: 1.9742 - learning_rate: 5.0611e-05
# Epoch 22/200
# 156/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9962 - loss: 0.1437
# Epoch 22: val_accuracy did not improve from 0.53003
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9962 - loss: 0.1437 - val_accuracy: 0.5268 - val_loss: 1.9679 - learning_rate: 5.0611e-05
# Epoch 23/200
# 156/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9969 - loss: 0.1381
# Epoch 23: val_accuracy did not improve from 0.53003
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9969 - loss: 0.1382 - val_accuracy: 0.5189 - val_loss: 1.9809 - learning_rate: 5.0611e-05
# Epoch 24/200
# 158/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9968 - loss: 0.1348
# Epoch 24: val_accuracy did not improve from 0.53003
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9968 - loss: 0.1348 - val_accuracy: 0.5117 - val_loss: 2.0254 - learning_rate: 5.0611e-05
# Epoch 25/200
# 149/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9980 - loss: 0.1309
# Epoch 25: val_accuracy did not improve from 0.53003
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9980 - loss: 0.1308 - val_accuracy: 0.5153 - val_loss: 2.0622 - learning_rate: 5.0611e-05
# Epoch 26/200
# 157/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9980 - loss: 0.1244
# Epoch 26: val_accuracy did not improve from 0.53003
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9980 - loss: 0.1244 - val_accuracy: 0.5222 - val_loss: 2.0825 - learning_rate: 5.0611e-05
# Epoch 27/200
# 142/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9974 - loss: 0.1226
# Epoch 27: ReduceLROnPlateau reducing learning rate to 1.5183248979155905e-05.
#
# Epoch 27: val_accuracy did not improve from 0.53003
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9974 - loss: 0.1226 - val_accuracy: 0.5127 - val_loss: 2.0882 - learning_rate: 5.0611e-05
# Epoch 28/200
# 157/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9979 - loss: 0.1196
# Epoch 28: val_accuracy did not improve from 0.53003
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9979 - loss: 0.1196 - val_accuracy: 0.5104 - val_loss: 2.1015 - learning_rate: 1.5183e-05
# Epoch 29/200
# 154/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9977 - loss: 0.1182
# Epoch 29: val_accuracy did not improve from 0.53003
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9977 - loss: 0.1182 - val_accuracy: 0.5111 - val_loss: 2.1084 - learning_rate: 1.5183e-05
# Epoch 30/200
# 157/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9986 - loss: 0.1150
# Epoch 30: val_accuracy did not improve from 0.53003
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9986 - loss: 0.1150 - val_accuracy: 0.5121 - val_loss: 2.1097 - learning_rate: 1.5183e-05
# Epoch 31/200
# 152/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9983 - loss: 0.1142
# Epoch 31: val_accuracy did not improve from 0.53003
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9983 - loss: 0.1141 - val_accuracy: 0.5124 - val_loss: 2.0944 - learning_rate: 1.5183e-05
# Epoch 32/200
# 142/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9981 - loss: 0.1134
# Epoch 32: val_accuracy did not improve from 0.53003
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9981 - loss: 0.1135 - val_accuracy: 0.5111 - val_loss: 2.1186 - learning_rate: 1.5183e-05
# Epoch 33/200
# 158/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9975 - loss: 0.1139
# Epoch 33: val_accuracy did not improve from 0.53003
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9975 - loss: 0.1139 - val_accuracy: 0.5144 - val_loss: 2.1271 - learning_rate: 1.5183e-05
# Epoch 34/200
# 145/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9990 - loss: 0.1115
# Epoch 34: val_accuracy did not improve from 0.53003
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9990 - loss: 0.1115 - val_accuracy: 0.5131 - val_loss: 2.1388 - learning_rate: 1.5183e-05
# Epoch 35/200
# 145/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9976 - loss: 0.1101
# Epoch 35: ReduceLROnPlateau reducing learning rate to 4.554974748316454e-06.
#
# Epoch 35: val_accuracy did not improve from 0.53003
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9976 - loss: 0.1101 - val_accuracy: 0.5098 - val_loss: 2.1481 - learning_rate: 1.5183e-05
# Epoch 36/200
# 144/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9986 - loss: 0.1093
# Epoch 36: val_accuracy did not improve from 0.53003
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9986 - loss: 0.1092 - val_accuracy: 0.5111 - val_loss: 2.1555 - learning_rate: 4.5550e-06
# Epoch 37/200
# 156/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9984 - loss: 0.1080
# Epoch 37: val_accuracy did not improve from 0.53003
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9984 - loss: 0.1080 - val_accuracy: 0.5137 - val_loss: 2.1519 - learning_rate: 4.5550e-06
# Epoch 38/200
# 144/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9989 - loss: 0.1068
# Epoch 38: val_accuracy did not improve from 0.53003
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9989 - loss: 0.1068 - val_accuracy: 0.5121 - val_loss: 2.1606 - learning_rate: 4.5550e-06
# Epoch 38: early stopping
# Restoring model weights from the end of the best epoch: 18.

# %%
lr_reducer, checkpoint, early_stopping = Callbacks('CNN2DGenderUHyper')
# Huấn luyện
historyCNN2DGenderUHyper = CNN2DGenderUHyper.fit(
    Xg_train_2D,  # Dữ liệu huấn luyện tăng cường
    yg_train_cat,  # Nhãn huấn luyện dạng one-hot
    epochs=200, 
    batch_size=64,  
    validation_data=(Xg_dev_2D, yg_dev_cat),  # Dữ liệu validation
    callbacks=[lr_reducer, checkpoint, early_stopping],  # Sử dụng các callback
    verbose=1  # Hiển thị tiến trình huấn luyện
)
# Out:
# Epoch 1/200
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7362 - loss: 0.7482
# Epoch 1: val_accuracy improved from -inf to 0.41351, saving model to best_CNN2DGenderUHyper.keras
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 10s 30ms/step - accuracy: 0.7367 - loss: 0.7471 - val_accuracy: 0.4135 - val_loss: 0.9037 - learning_rate: 4.2575e-04
# Epoch 2/200
# 140/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9208 - loss: 0.3673
# Epoch 2: val_accuracy improved from 0.41351 to 0.74804, saving model to best_CNN2DGenderUHyper.keras
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9212 - loss: 0.3654 - val_accuracy: 0.7480 - val_loss: 0.7175 - learning_rate: 4.2575e-04
# Epoch 3/200
# 152/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9504 - loss: 0.2850
# Epoch 3: val_accuracy improved from 0.74804 to 0.82017, saving model to best_CNN2DGenderUHyper.keras
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9500 - loss: 0.2852 - val_accuracy: 0.8202 - val_loss: 0.5564 - learning_rate: 4.2575e-04
# Epoch 4/200
# 141/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9574 - loss: 0.2471
# Epoch 4: val_accuracy improved from 0.82017 to 0.83551, saving model to best_CNN2DGenderUHyper.keras
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9576 - loss: 0.2464 - val_accuracy: 0.8355 - val_loss: 0.5859 - learning_rate: 4.2575e-04
# Epoch 5/200
# 140/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9659 - loss: 0.2144
# Epoch 5: val_accuracy did not improve from 0.83551
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9661 - loss: 0.2143 - val_accuracy: 0.8257 - val_loss: 0.6224 - learning_rate: 4.2575e-04
# Epoch 6/200
# 140/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9707 - loss: 0.1925
# Epoch 6: val_accuracy did not improve from 0.83551
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9707 - loss: 0.1922 - val_accuracy: 0.8143 - val_loss: 0.6549 - learning_rate: 4.2575e-04
# Epoch 7/200
# 156/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9712 - loss: 0.1885
# Epoch 7: val_accuracy did not improve from 0.83551
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9713 - loss: 0.1882 - val_accuracy: 0.8260 - val_loss: 0.6856 - learning_rate: 4.2575e-04
# Epoch 8/200
# 141/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9794 - loss: 0.1625
# Epoch 8: val_accuracy did not improve from 0.83551
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9794 - loss: 0.1617 - val_accuracy: 0.8287 - val_loss: 0.7070 - learning_rate: 4.2575e-04
# Epoch 9/200
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9831 - loss: 0.1419
# Epoch 9: val_accuracy did not improve from 0.83551
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9831 - loss: 0.1419 - val_accuracy: 0.8176 - val_loss: 0.8078 - learning_rate: 4.2575e-04
# Epoch 10/200
# 140/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9872 - loss: 0.1265
# Epoch 10: val_accuracy did not improve from 0.83551
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9872 - loss: 0.1265 - val_accuracy: 0.8146 - val_loss: 0.8622 - learning_rate: 4.2575e-04
# Epoch 11/200
# 141/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9858 - loss: 0.1230
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.000127724846242927.
#
# Epoch 11: val_accuracy did not improve from 0.83551
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9856 - loss: 0.1235 - val_accuracy: 0.8306 - val_loss: 0.7576 - learning_rate: 4.2575e-04
# Epoch 12/200
# 140/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9931 - loss: 0.1061
# Epoch 12: val_accuracy improved from 0.83551 to 0.84138, saving model to best_CNN2DGenderUHyper.keras
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9931 - loss: 0.1059 - val_accuracy: 0.8414 - val_loss: 0.6474 - learning_rate: 1.2772e-04
# Epoch 13/200
# 156/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9953 - loss: 0.0979
# Epoch 13: val_accuracy did not improve from 0.84138
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9953 - loss: 0.0979 - val_accuracy: 0.8326 - val_loss: 0.7330 - learning_rate: 1.2772e-04
# Epoch 14/200
# 156/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9982 - loss: 0.0898
# Epoch 14: val_accuracy did not improve from 0.84138
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9982 - loss: 0.0898 - val_accuracy: 0.8322 - val_loss: 0.7247 - learning_rate: 1.2772e-04
# Epoch 15/200
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9970 - loss: 0.0885
# Epoch 15: val_accuracy did not improve from 0.84138
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9970 - loss: 0.0885 - val_accuracy: 0.8398 - val_loss: 0.8051 - learning_rate: 1.2772e-04
# Epoch 16/200
# 156/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9974 - loss: 0.0862
# Epoch 16: val_accuracy did not improve from 0.84138
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9974 - loss: 0.0861 - val_accuracy: 0.8371 - val_loss: 0.7699 - learning_rate: 1.2772e-04
# Epoch 17/200
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9985 - loss: 0.0827
# Epoch 17: val_accuracy did not improve from 0.84138
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9985 - loss: 0.0827 - val_accuracy: 0.8358 - val_loss: 0.7737 - learning_rate: 1.2772e-04
# Epoch 18/200
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9985 - loss: 0.0792
# Epoch 18: val_accuracy did not improve from 0.84138
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9985 - loss: 0.0792 - val_accuracy: 0.8381 - val_loss: 0.8074 - learning_rate: 1.2772e-04
# Epoch 19/200
# 157/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9975 - loss: 0.0796
# Epoch 19: ReduceLROnPlateau reducing learning rate to 3.831745561910793e-05.
#
# Epoch 19: val_accuracy did not improve from 0.84138
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9975 - loss: 0.0796 - val_accuracy: 0.8280 - val_loss: 0.8198 - learning_rate: 1.2772e-04
# Epoch 20/200
# 144/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9980 - loss: 0.0761
# Epoch 20: val_accuracy did not improve from 0.84138
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9981 - loss: 0.0761 - val_accuracy: 0.8322 - val_loss: 0.8213 - learning_rate: 3.8317e-05
# Epoch 21/200
# 157/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9991 - loss: 0.0742
# Epoch 21: val_accuracy did not improve from 0.84138
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9991 - loss: 0.0742 - val_accuracy: 0.8332 - val_loss: 0.8523 - learning_rate: 3.8317e-05
# Epoch 22/200
# 158/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9993 - loss: 0.0738
# Epoch 22: val_accuracy did not improve from 0.84138
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9993 - loss: 0.0738 - val_accuracy: 0.8316 - val_loss: 0.8355 - learning_rate: 3.8317e-05
# Epoch 23/200
# 157/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9985 - loss: 0.0734
# Epoch 23: val_accuracy did not improve from 0.84138
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9985 - loss: 0.0734 - val_accuracy: 0.8309 - val_loss: 0.8475 - learning_rate: 3.8317e-05
# Epoch 24/200
# 158/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9991 - loss: 0.0710
# Epoch 24: val_accuracy did not improve from 0.84138
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9991 - loss: 0.0710 - val_accuracy: 0.8326 - val_loss: 0.8226 - learning_rate: 3.8317e-05
# Epoch 25/200
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9995 - loss: 0.0706
# Epoch 25: val_accuracy did not improve from 0.84138
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9995 - loss: 0.0706 - val_accuracy: 0.8342 - val_loss: 0.8543 - learning_rate: 3.8317e-05
# Epoch 26/200
# 156/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9996 - loss: 0.0692
# Epoch 26: val_accuracy did not improve from 0.84138
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9996 - loss: 0.0692 - val_accuracy: 0.8322 - val_loss: 0.8600 - learning_rate: 3.8317e-05
# Epoch 27/200
# 156/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9984 - loss: 0.0709
# Epoch 27: ReduceLROnPlateau reducing learning rate to 1.149523668573238e-05.
#
# Epoch 27: val_accuracy did not improve from 0.84138
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9984 - loss: 0.0708 - val_accuracy: 0.8332 - val_loss: 0.8564 - learning_rate: 3.8317e-05
# Epoch 28/200
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9994 - loss: 0.0689
# Epoch 28: val_accuracy did not improve from 0.84138
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9994 - loss: 0.0689 - val_accuracy: 0.8329 - val_loss: 0.8862 - learning_rate: 1.1495e-05
# Epoch 29/200
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9997 - loss: 0.0682
# Epoch 29: val_accuracy did not improve from 0.84138
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9997 - loss: 0.0682 - val_accuracy: 0.8319 - val_loss: 0.8854 - learning_rate: 1.1495e-05
# Epoch 30/200
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9997 - loss: 0.0674
# Epoch 30: val_accuracy did not improve from 0.84138
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9997 - loss: 0.0674 - val_accuracy: 0.8322 - val_loss: 0.8889 - learning_rate: 1.1495e-05
# Epoch 31/200
# 140/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9999 - loss: 0.0665
# Epoch 31: val_accuracy did not improve from 0.84138
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9999 - loss: 0.0665 - val_accuracy: 0.8319 - val_loss: 0.8935 - learning_rate: 1.1495e-05
# Epoch 32/200
# 157/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9998 - loss: 0.0673
# Epoch 32: val_accuracy did not improve from 0.84138
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9998 - loss: 0.0673 - val_accuracy: 0.8332 - val_loss: 0.8797 - learning_rate: 1.1495e-05
# Epoch 32: early stopping
# Restoring model weights from the end of the best epoch: 12.

# %%
Evaluateandlogperformance(CNN2DRegionUHyper, historyCNN2DRegionUHyper, Xr_test_2D, yr_test_cat, 'CNN2DRegionUHyper', detail = False)
Evaluateandlogperformance(CNN2DGenderUHyper, historyCNN2DGenderUHyper, Xg_test_2D, yg_test_cat, 'CNN2DGenderUHyper', detail = False)
# Out:
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.5340 - loss: 1.7020
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8932 - loss: 0.4441

# %%
compute_confusion_matrix(CNN2DRegionUHyper, Xr_test_2D, yr_test_cat, 'CNN2DRegionUHyper', 3)
compute_confusion_matrix(CNN2DGenderUHyper, Xg_test_2D, yg_test_cat, 'CNN2DGenderUHyper', 2)
# Out:
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.59      0.62      0.60      1252
#            1       0.49      0.54      0.52       848
#            2       0.53      0.44      0.48       852
#
#     accuracy                           0.54      2952
#    macro avg       0.54      0.53      0.53      2952
# weighted avg       0.54      0.54      0.54      2952
#
#
# Detailed Metrics by Class:
#
# Class 0:
# Precision: 0.5905
# Recall: 0.6150
# F1-score: 0.6025
#
# Class 1:
# Precision: 0.4904
# Recall: 0.5436
# F1-score: 0.5157
#
# Class 2:
# Precision: 0.5282
# Recall: 0.4390
# F1-score: 0.4795
#
# Overall Metrics:
# Average Precision: 0.5438
# Average Recall: 0.5437
# Average F1-score: 0.5421
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.97      0.93      1967
#            1       0.93      0.76      0.83       985
#
#     accuracy                           0.90      2952
#    macro avg       0.91      0.86      0.88      2952
# weighted avg       0.90      0.90      0.90      2952
#
#
# Detailed Metrics by Class:
#
# Class 0:
# Precision: 0.8888
# Recall: 0.9715
# F1-score: 0.9283
#
# Class 1:
# Precision: 0.9302
# Recall: 0.7574
# F1-score: 0.8349
#
# Overall Metrics:
# Average Precision: 0.9026
# Average Recall: 0.9001
# Average F1-score: 0.8972

# %%
CNN2DRegionUHyper.summary()
CNN2DGenderUHyper.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_1 (Conv2D)               │ (None, 7, 10, 80)      │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 7, 10, 80)      │           320 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 7, 10, 80)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 7, 10, 32)      │        64,032 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 7, 10, 32)      │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 7, 10, 32)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 2240)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 80)             │       179,280 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 80)             │           320 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 80)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 8)              │           648 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 8)              │            32 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 8)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 3)              │            27 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 739,803 (2.82 MB)
#  Trainable params: 246,467 (962.76 KB)
#  Non-trainable params: 400 (1.56 KB)
#  Optimizer params: 492,936 (1.88 MB)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)               │ (None, 7, 10, 48)      │         1,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 7, 10, 48)      │           192 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 7, 10, 48)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 7, 10, 16)      │         6,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 7, 10, 16)      │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 7, 10, 16)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 1120)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 48)             │        53,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 48)             │           192 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 48)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 24)             │         1,176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 24)             │            96 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 24)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 2)              │            50 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 190,720 (745.00 KB)
#  Trainable params: 63,482 (247.98 KB)
#  Non-trainable params: 272 (1.06 KB)
#  Optimizer params: 126,966 (495.96 KB)

# %%
CNN2DRegionUHyper.save('best_region_recognition_model_update.keras')
CNN2DGenderUHyper.save("best_gender_recognition_model_update.keras")

# %% [markdown]
# # Total

# %% [markdown]
# ## Model
